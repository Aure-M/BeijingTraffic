# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Python 3 program to calculate Distance Between Two Points on Earth
from math import radians, cos, sin, asin, sqrt
def distance(lat1, lat2, lon1, lon2):
	
	# The math module contains a function named
	# radians which converts from degrees to radians.
	lon1 = radians(lon1)
	lon2 = radians(lon2)
	lat1 = radians(lat1)
	lat2 = radians(lat2)
	
	# Haversine formula
	dlon = lon2 - lon1
	dlat = lat2 - lat1
	a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2

	c = 2 * asin(sqrt(a))
	
	# Radius of earth in kilometers. Use 3956 for miles
	r = 6371
	
	# calculate the result
	return(c * r)
	
	
def getDistance(A,B):
    return distance(A["latitude"],B["latitude"],A["longitude"],B["longitude"])

def isinBeijing(data):
    beijing = {"lat":40.190632, "lon":116.412144,"radius":sqrt(16411/(np.pi*2))}
    res = []
    for i in range(len(data)):
        if beijing["radius"] >= distance(data.iloc[i]["latitude"],beijing["lat"],data.iloc[i]["longitude"],beijing["lon"]):
            res.append(True)
        else:
            res.append(False)
    return res
def defineZones(data,zoneRadius=15):
    locations = data[["longitude","latitude"]].value_counts()
    centers = []
    for current in locations.index.to_list():
        shoulBeACenter = True
        for c in centers:
            if distance(current[1],c[1],current[0],c[0])<zoneRadius:
                shoulBeACenter = False
                break
        if shoulBeACenter:
            centers.append(current)
    
    return centers
def fillZone(data,centers):
    res = []
    for i in range(len(data)):
        print(i)
        l = []
        for c in centers:
            l.append(distance(c[1],data.iloc[i]["latitude"],c[0],data.iloc[i]["longitude"]))
        res.append(np.argmin(l)) 
    return res

# %%
beijing = {"lat":40.190632, "lon":116.412144,"radius":sqrt(16411/(np.pi*2))}

# %%
taxis = pd.read_csv("taxis2.csv",index_col="datetime")
taxis.index = pd.to_datetime(taxis.index)

# %% [markdown]
# Taxis average speed between two points

# %%
taxis.head()
# Out:
#                      taxiId  longitude  latitude  dayMoment  hours days  \
# datetime
# 2008-02-02 15:36:08       1  116.51172  39.92123  afternoon     15  Sat
# 2008-02-02 15:46:08       1  116.51135  39.93883  afternoon     15  Sat
# 2008-02-02 15:56:08       1  116.51627  39.91034  afternoon     15  Sat
# 2008-02-02 16:06:08       1  116.47186  39.91248  afternoon     16  Sat
# 2008-02-02 16:16:08       1  116.47217  39.92498  afternoon     16  Sat
#
#                      res_T     res_D     speed  isinBeijing  zone
# datetime
# 2008-02-02 15:36:08    NaN       NaN       NaN         True     2
# 2008-02-02 15:46:08   10.0  1.957285  0.195728         True     2
# 2008-02-02 15:56:08   10.0  3.195604  0.319560         True     2
# 2008-02-02 16:06:08   10.0  3.795226  0.379523         True     2
# 2008-02-02 16:16:08   10.0  1.390188  0.139019         True     2

# %% [markdown]
# ----

# %% [markdown]
# Cleaning

# %%
taxis.shape
# Out:
# (474911, 11)

# %%
import folium

# %%
t1 = taxis[(taxis["taxiId"]==2)|(taxis["taxiId"]==1)|(taxis["taxiId"]==5)]
color = {"morning":"yellow","afternoon":"orange","night":"blue","afterMidnight":"black",}
map = folium.Map(location=[beijing["lat"], beijing["lon"]])
folium.TileLayer('stamenterrain').add_to(map)
for ind, lat, lon, m in t1[['latitude', 'longitude', 'dayMoment']].itertuples():
    map.add_child(folium.RegularPolygonMarker(location=[lat,lon],
                       color=color[m], radius=5))

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b84abf69fe184e07fabdd0c0ef0b4d9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b84abf69fe184e07fabdd0c0ef0b4d9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b84abf69fe184e07fabdd0c0ef0b4d9b = L.map(
#                 &quot;map_b84abf69fe184e07fabdd0c0ef0b4d9b&quot;,
#                 {
#                     center: [40.190632, 116.412144],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_234a2fa9dbdb488bead1e08adbccb20b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var tile_layer_5c7d32c29fb18ec6a2320742dae84b85 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var regular_polygon_marker_75b35fcdb44f940b51996a1431e68a24 = new L.RegularPolygonMarker(
#                 [39.92123, 116.51172],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var regular_polygon_marker_1a24be41b9cf0c516d2bf46cd57d7ff8 = new L.RegularPolygonMarker(
#                 [39.93883, 116.51135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var regular_polygon_marker_cd369fbdfbc1722e7387693e304f9d7d = new L.RegularPolygonMarker(
#                 [39.91034, 116.51627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var regular_polygon_marker_1c7a28800d56367be0892390b8a5494b = new L.RegularPolygonMarker(
#                 [39.91248, 116.47186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b84abf69fe184e07fabdd0c0ef0b4d9b);
#
#
#             var regular_polygon_marker_96ccc86df685028f491e8f34467aab48 = new L.RegularPolygonMarker(
#                 [39.92498, 116.47217],
#                 {&quot;bubblingMous

# %%
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

colors = list(colors.values())[20:]

# %%
centers = defineZones(taxis)

# %%
t1 = taxis[taxis["taxiId"]==2]
map = folium.Map(location=[beijing["lat"], beijing["lon"]])
folium.TileLayer('stamenterrain').add_to(map)
for ind, lat, lon, zone in t1[['latitude', 'longitude', 'zone']].itertuples():
    map.add_child(folium.RegularPolygonMarker(location=[lat,lon],
                       color=colors[zone], radius=3))
for i in range(len(centers)):
    map.add_child(folium.RegularPolygonMarker(
        location=[centers[i][1],centers[i][0]],
        color="black", radius=5))
    map.add_child(folium.CircleMarker(
        location = [centers[i][1],centers[i][0]],
        popup="zone_{}".format(i),
        color = colors[i],
        radius = 75,
        fill = True)
    )
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49a52346bc2575e88ee6efecbe94df57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49a52346bc2575e88ee6efecbe94df57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_49a52346bc2575e88ee6efecbe94df57 = L.map(
#                 &quot;map_49a52346bc2575e88ee6efecbe94df57&quot;,
#                 {
#                     center: [40.190632, 116.412144],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebbbf0bf826728351a780802834bd131 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var tile_layer_172ab49705043b8734b620f7268e34a7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var regular_polygon_marker_6d7c4fd7b249e4a7149bf6e29d84e830 = new L.RegularPolygonMarker(
#                 [39.88781, 116.36422],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DEB887&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#DEB887&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var regular_polygon_marker_70554c9ed399d878c5ced4cd2a8eb7e5 = new L.RegularPolygonMarker(
#                 [39.88782, 116.37481],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DEB887&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#DEB887&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var regular_polygon_marker_246fab78b771a3a0f22cbb206acb1a19 = new L.RegularPolygonMarker(
#                 [39.88791, 116.37677],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DEB887&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#DEB887&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var regular_polygon_marker_e8c7ed72648ee91db3e1786a92edaff1 = new L.RegularPolygonMarker(
#                 [39.88795, 116.38033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5F9EA0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#5F9EA0&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49a52346bc2575e88ee6efecbe94df57);
#
#
#             var regular_polygon_marker_2746d68304f1348b6b2ce7b1f6e7c08f = new L.RegularPolygonMarker(
#                 [39.89014, 116.39392],
#                 {&quot;bubb

# %%
taxis["zone"].value_counts()
# Out:
# 2     163306
# 1     124851
# 0      87802
# 11     18567
# 3      18505
# 12     15229
# 10     14525
# 7       8736
# 4       5171
# 25      3846
# 13      3438
# 8       1799
# 24      1705
# 6       1337
# 17      1328
# 15      1191
# 18       994
# 14       899
# 5        599
# 23       596
# 19       170
# 16       129
# 22        82
# 21        53
# 9         31
# 20        21
# 26         1
# Name: zone, dtype: int64

# %%
import datetime

# %%
train1_df = pd.read_csv("taxis2.csv")
train1_df['datetime'] = pd.to_datetime(train1_df['datetime'])
train1_df['weekday'] = train1_df['datetime'].dt.weekday
train1_df['hour'] = train1_df['datetime'].dt.hour
train1_df['minute'] = train1_df['datetime'].dt.minute

# %%
train1_df
# Out:
#                   datetime  taxiId  longitude  latitude      dayMoment  hours  \
# 0      2008-02-02 15:36:08       1  116.51172  39.92123      afternoon     15
# 1      2008-02-02 15:46:08       1  116.51135  39.93883      afternoon     15
# 2      2008-02-02 15:56:08       1  116.51627  39.91034      afternoon     15
# 3      2008-02-02 16:06:08       1  116.47186  39.91248      afternoon     16
# 4      2008-02-02 16:16:08       1  116.47217  39.92498      afternoon     16
# ...                    ...     ...        ...       ...            ...    ...
# 474906 2008-02-07 13:03:05   10174  116.45776  39.79692      afternoon     13
# 474907 2008-02-07 06:15:44   10216  116.35936  39.96986        morning      6
# 474908 2008-02-06 08:51:30   10252  116.77860  40.36083        morning      8
# 474909 2008-02-05 06:05:50   10299  116.31430  39.85684        morning      6
# 474910 2008-02-03 04:19:46   10322  116.63101  40.33172  afterMidnight      4
#
#        days      res_T     res_D     speed  isinBeijing  zone  weekday  hour  \
# 0       Sat        NaN       NaN       NaN         True     2        5    15
# 1       Sat  10.000000  1.957285  0.195728         True     2        5    15
# 2       Sat  10.000000  3.195604  0.319560         True     2        5    15
# 3       Sat  10.000000  3.795226  0.379523         True     2        5    16
# 4       Sat  10.000000  1.390188  0.139019         True     2        5    16
# ...     ...        ...       ...       ...          ...   ...      ...   ...
# 474906  Thu   4.716667  1.330247  0.282031         True     1        3    13
# 474907  Thu   5.000000  0.110728  0.022146         True     2        3     6
# 474908  Wed   4.733333  0.000000  0.000000         True    13        2     8
# 474909  Tue   5.000000  0.001402  0.000280         True     0        1     6
# 474910  Sun   5.033333  0.000000  0.000000         True    15        6     4
#
#         minute
# 0           36
# 1           46
# 2           56
# 3            6
# 4           16
# ...        ...
# 474906       3
# 474907      15
# 474908      51
# 474909       5
# 474910      19
#
# [474911 rows x 15 columns]

# %%
from iteration_utilities import duplicates
from iteration_utilities import unique_everseen

# %%
dup=pd.DataFrame(train1_df,columns=['longitude','latitude'])

# %%
dup
# Out:
#         longitude  latitude
# 0       116.51172  39.92123
# 1       116.51135  39.93883
# 2       116.51627  39.91034
# 3       116.47186  39.91248
# 4       116.47217  39.92498
# ...           ...       ...
# 474906  116.45776  39.79692
# 474907  116.35936  39.96986
# 474908  116.77860  40.36083
# 474909  116.31430  39.85684
# 474910  116.63101  40.33172
#
# [474911 rows x 2 columns]

# %%
sam =list(unique_everseen(duplicates(dup['longitude'])))

# %%
sam
# Out:
# [116.69168,
#  116.69167,
#  116.69172,
#  116.69171,
#  116.6917,
#  116.69164,
#  116.69176,
#  116.69156,
#  116.69162,
#  116.69161,
#  116.69165,
#  116.69169,
#  116.69157,
#  116.69155,
#  116.69159,
#  116.6916,
#  116.69158,
#  116.69163,
#  116.69166,
#  116.69149,
#  116.6915,
#  116.69152,
#  116.69177,
#  116.69154,
#  116.69153,
#  116.47179,
#  116.69151,
#  116.69173,
#  116.69182,
#  116.69185,
#  116.69174,
#  116.69146,
#  116.69175,
#  116.69179,
#  116.69136,
#  116.69141,
#  116.69184,
#  116.69137,
#  116.69145,
#  116.69147,
#  116.48347,
#  116.4215,
#  116.4554,
#  116.45478,
#  116.48377,
#  116.45531,
#  116.48364,
#  116.47237,
#  116.45105,
#  116.45053,
#  116.44439,
#  116.45766,
#  116.4496,
#  116.45525,
#  116.45551,
#  116.45507,
#  116.44961,
#  116.4581,
#  116.45,
#  116.38529,
#  116.37216,
#  116.45527,
#  116.47166,
#  116.45774,
#  116.44972,
#  116.42931,
#  116.3571,
#  116.41531,
#  116.40533,
#  116.45765,
#  116.45601,
#  116.45552,
#  116.45474,
#  116.45526,
#  116.45529,
#  116.44953,
#  116.44324,
#  116.45535,
#  116.45208,
#  116.44429,
#  116.44434,
#  116.35982,
#  116.4555,
#  116.455,
#  116.4497,
#  116.45458,
#  116.45377,
#  116.47108,
#  116.44405,
#  116.44414,
#  116.45594,
#  116.45753,
#  116.45544,
#  116.45181,
#  116.44031,
#  116.45471,
#  116.4553,
#  116.43354,
#  116.40728,
#  116.38875,
#  116.45382,
#  116.46554,
#  116.48335,
#  116.50839,
#  116.42972,
#  116.41173,
#  116.41211,
#  116.41291,
#  116.44463,
#  116.44466,
#  116.46159,
#  116.4616,
#  116.45075,
#  116.46168,
#  116.46164,
#  116.49592,
#  116.45555,
#  116.45559,
#  116.35042,
#  116.45005,
#  116.44047,
#  116.49721,
#  116.49723,
#  116.41487,
#  116.45533,
#  116.39418,
#  116.40834,
#  116.35724,
#  116.39512,
#  116.42516,
#  116.44985,
#  116.45556,
#  116.42559,
#  116.39928,
#  116.40135,
#  116.45548,
#  116.45579,
#  116.45523,
#  116.53661,
#  116.54184,
#  116.42745,
#  116.42772,
#  116.42752,
#  116.42598,
#  116.42543,
#  116.42425,
#  116.41298,
#  116.40477,
#  116.40463,
#  116.40252,
#  116.4003,
#  116.40023,
#  116.40035,
#  116.39897,
#  116.399,
#  116.40025,
#  116.42058,
#  116.41837,
#  116.41825,
#  116.41833,
#  116.41855,
#  116.42955,
#  116.42977,
#  116.42943,
#  116.42798,
#  116.42988,
#  116.42993,
#  116.4327,
#  116.43285,
#  116.44955,
#  116.44967,
#  116.44977,
#  116.44722,
#  116.44418,
#  116.44398,
#  116.43918,
#  116.43932,
#  116.4392,
#  116.43808,
#  116.4364,
#  116.4302,
#  116.42923,
#  116.42825,
#  116.42832,
#  116.4304,
#  116.43747,
#  116.4375,
#  116.43745,
#  116.43737,
#  116.4344,
#  116.43397,
#  116.4303,
#  116.43068,
#  116.43432,
#  116.43447,
#  116.43453,
#  116.44327,
#  116.4511,
#  116.45107,
#  116.45372,
#  116.45402,
#  116.45403,
#  116.45375,
#  116.45137,
#  116.45158,
#  116.45443,
#  116.51115,
#  116.49705,
#  116.49238,
#  116.48488,
#  116.46352,
#  116.46052,
#  116.45578,
#  116.45593,
#  116.45572,
#  116.45223,
#  116.44462,
#  116.44442,
#  116.44423,
#  116.44422,
#  116.44413,
#  116.44397,
#  116.43507,
#  116.42845,
#  116.42698,
#  116.4257,
#  116.42585,
#  116.426,
#  116.42715,
#  116.42723,
#  116.42713,
#  116.42582,
#  116.42572,
#  116.42395,
#  116.42362,
#  116.41918,
#  116.39982,
#  116.39087,
#  116.38378,
#  116.38988,
#  116.39122,
#  116.39102,
#  116.3936,
#  116.39625,
#  116.39837,
#  116.39857,
#  116.39878,
#  116.39882,
#  116.3989,
#  116.39963,
#  116.39973,
#  116.39953,
#  116.39862,
#  116.39903,
#  116.39908,
#  116.39933,
#  116.40078,
#  116.40547,
#  116.40555,
#  116.40553,
#  116.4056,
#  116.40588,
#  ...]

# %%
sam=train1_df[(train1_df['longitude']==116.51172) &(train1_df['latitude']==39.92123)|(train1_df['longitude']==116.51135) &(train1_df['latitude']==39.93883)]

# %%
sam
# Out:
#                   datetime  taxiId  longitude  latitude  dayMoment  hours  \
# 0      2008-02-02 15:36:08       1  116.51172  39.92123  afternoon     15
# 1      2008-02-02 15:46:08       1  116.51135  39.93883  afternoon     15
# 404559 2008-02-07 19:00:30     715  116.51172  39.92123      night     19
#
#        days      res_T     res_D     speed  isinBeijing  zone  weekday  hour  \
# 0       Sat        NaN       NaN       NaN         True     2        5    15
# 1       Sat  10.000000  1.957285  0.195728         True     2        5    15
# 404559  Thu   0.166667  0.034230  0.205380         True     2        3    19
#
#         minute
# 0           36
# 1           46
# 404559       0

# %%
sam=sam[(sam['taxiId']==1)]

# %%
sam1=sam['hour']*60+sam['minute']

# %%
sam=sam1.shift(-1)-sam1

# %%
sam=sam.dropna()
sam=np.mean(sam)

# %%
sam
# Out:
# 10.0
